# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#combine player stats
# stats_total=pd.read_csv('../Resources/summarized_offensive_stats.csv')
# players_total=pd.read_csv('../Resources/offensive_players.csv')
# combined_df=pd.merge(players_total,stats_total, on='player_id')
#combined_df.to_csv('../Resources/total_combined_data.csv')

# %%
# filtered_df=pd.read_csv('../Resources/total_combined_data.csv')
filtered_df=pd.read_csv('../Resources/brett_test.csv')

# %%
# filtered_df = filtered_df.drop(columns=['Unnamed: 0','Unnamed: 0_x','name','height','birth_date','birth_place','death_date','high_school','current_salary','hof_induction_year','position','Unnamed: 0_y'])

# %%
filtered_df=filtered_df[filtered_df['year'] >2016]
# filtered_df['current_team'].replace(np.nan, 'None', inplace=True)
# filtered_df['college'].replace(np.nan, 'None', inplace=True)
# filtered_df['draft_team'].replace(np.nan, 'None', inplace=True)
filtered_df['draft_round'].replace('None', 8, inplace=True)
filtered_df['draft_position'].replace('None', 225, inplace=True)
# filtered_df=filtered_df.replace(np.nan,0)

# %%
filtered_df.info()
filtered_df.to_csv('../Resources/final_file.csv')

# %%
QB_position=filtered_df.loc[filtered_df['position_cleaned'] == 'QB']
RB_position=filtered_df.loc[filtered_df['position_cleaned'] == 'RB']
WR_position=filtered_df.loc[filtered_df['position_cleaned'] == 'WR']
TE_position=filtered_df.loc[filtered_df['position_cleaned'] == 'TE']
# QB_position.to_csv('../Resources/QB_stats.csv')
# RB_position.to_csv('../Resources/RB_stats.csv')
# WR_position.to_csv('../Resources/WR_stats.csv')
# TE_position.to_csv('../Resources/TE_stats.csv')

# %%
QB_position_filtered=QB_position

# %%
QB_position_filtered
# Out:
#       player_id  weight  draft_round  draft_position  draft_year  \
# 108        6975     221            7             250        2005
# 109        6975     221            7             250        2005
# 124       14490     220            5             164        2014
# 148        9636     228            2              57        2008
# 157       14580     212            3              81        2002
# ...         ...     ...          ...             ...         ...
# 3195      14004     237            1              16        2013
# 3196      14004     237            1              16        2013
# 3321      22087     248            4             120        2014
# 3322      22087     248            4             120        2014
# 3380      13753     244            1              26        2016
#
#      game_location position_cleaned  height_inches  year  player_age  ...  \
# 108              A               QB             74  2017  12768.0625  ...
# ...

# %%
#Neural net with only statistical data, and position encoded.
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

X = QB_position_filtered.iloc[:, 0:-1].values
y = QB_position_filtered.iloc[:, -1].values
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0,5,6])], remainder='passthrough')
#X = np.array(ct.fit_transform(X))
X = ct.fit_transform(X)
X = np.asarray(X).astype(np.float32)

X[0]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train[0]
# Out:
# array([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#        0.0000e+00, 1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00,
# ...

# %%
# from sklearn.preprocessing import StandardScaler

# X_scaler = StandardScaler().fit(X_train)

# %%
# X_train_scaled = X_scaler.transform(X_train)
# X_test_scaled = X_scaler.transform(X_test)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
#  # One-hot encoding
# y_train=y_train.reshape(-1,1)
# y_test=y_test.reshape(-1,1)

# y_scaler = StandardScaler().fit(y_train)
# y_train_scaled = y_scaler.transform(y_train)
# y_test_scaled = y_scaler.transform(y_test)
# y_train_categorical = to_categorical(y_train)
# y_test_categorical = to_categorical(y_test)
# y_test_categorical

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
from tensorflow.keras.layers import Dense
number_inputs = 100
number_hidden_nodes = 4
model.add(Dense(units=number_hidden_nodes,
                activation='relu', input_dim=number_inputs))
model.add(Dense(units=1, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 4)                 404
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 5
# ...
# Total params: 409
# Trainable params: 409
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 2/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 3/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 4/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 5/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 6/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 7/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 8/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 9/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 10/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 11/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 12/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 13/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 14/1000
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
# Epoch 15/1000
# ...

# %%
model_loss, model_accuracy = model.evaluate(
    X_train, y_train, verbose=2)
# Out:
# 3/3 - 0s - loss: 0.0000e+00 - accuracy: 0.0000e+00
