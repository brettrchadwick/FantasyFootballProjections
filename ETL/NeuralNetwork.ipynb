# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import pandas as pd

# %%
#combine player stats
stats_total=pd.read_csv('../Resources/summarized_offensive_stats.csv')
players_total=pd.read_csv('../Resources/offensive_players.csv')
combined_df=pd.merge(players_total,stats_total, on='player_id')
#combined_df.to_csv('../Resources/total_combined_data.csv')

# %%
filtered_df=pd.read_csv('../Resources/total_combined_data.csv')

# %%
filtered_df=filtered_df[filtered_df['year'] >2014]
filtered_df['current_team'].replace(np.nan, 'None', inplace=True)
filtered_df['college'].replace(np.nan, 'None', inplace=True)
filtered_df['draft_team'].replace(np.nan, 'None', inplace=True)
filtered_df['draft_round'].replace(np.nan, 'None', inplace=True)
filtered_df['draft_position'].replace(np.nan, 'None', inplace=True)

# %%
filtered_df
# Out:
#                   name position  height_inches  weight current_team  \
# 63     Chandler Worthy       WR           69.0   173.0         None
# 64     Chandler Worthy       WR           69.0   173.0         None
# 77       MyCole Pruitt       TE           74.0   251.0         None
# 78       MyCole Pruitt       TE           74.0   251.0         None
# 79       MyCole Pruitt       TE           74.0   251.0         None
# ...                ...      ...            ...     ...          ...
# 57184   Terrell Watson       RB           73.0   240.0         None
# 57220   Justin Forsett       RB           68.0   190.0         None
# 57221   Justin Forsett       RB           68.0   190.0         None
# 57222   Justin Forsett       RB           68.0   190.0         None
# 57223   Justin Forsett       RB           68.0   190.0         None
#
#                  college         draft_team draft_round draft_position  \
# 63                  Troy               None        None           None
# ...

# %%
QB_position=filtered_df.loc[filtered_df['position'] == 'QB']
RB_position=filtered_df.loc[filtered_df['position'] == 'RB']
WR_position=filtered_df.loc[filtered_df['position'] == 'WR']
TE_position=filtered_df.loc[filtered_df['position'] == 'TE']
QB_position.to_csv('../Resources/QB_stats.csv')
RB_position.to_csv('../Resources/RB_stats.csv')
WR_position.to_csv('../Resources/WR_stats.csv')
TE_position.to_csv('../Resources/TE_stats.csv')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0,1,4,5,6])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-28284a3b84f3> in <module>
#       2 from sklearn.preprocessing import OneHotEncoder
#       3 ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0,1,4,5,6])], remainder='passthrough')
# ----> 4 X = np.array(ct.fit_transform(X))
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/compose/_column_transformer.py in fit_transform(self, X, y)
#     529         self._validate_remainder(X)
#     530
# --> 531         result = self._fit_transform(X, y, _fit_transform_one)
#     532
#     533         if not result:
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     465                     message=self._log_message(name, idx, len(transformers)))
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

# %%
 # One-hot encoding
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)
y_train_categorical

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
from tensorflow.keras.layers import Dense
number_inputs = 3
number_hidden_nodes = 4
model.add(Dense(units=number_hidden_nodes,
                activation='relu', input_dim=number_inputs))
